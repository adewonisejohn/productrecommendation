# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from datetime import datetime
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_excel('./ML Project_customer_product.xlsx')  
data2 = pd.read_excel('./ML Project_product_interaction.xlsx')

# %%
data1.head()
# Out:
#    product_label  product_id product_category    product_major  \
# 0        1150536     7187101   CANNED AND DRY     BAKING NEEDS
# 1        2049209     7066461          SEAFOOD  FRZN PREPRD SFD
# 2         874129     7203474          POULTRY    POULTRY FRESH
# 3        1967472     4909499          PRODUCE  VEGETABLE FRESH
# 4         346288     4096368   CANNED AND DRY  SAUCES/SAUC MIX
#
#              product_brand  Price  case_qty  ordr_qty  customer_label cuisine  \
# 0              GHIRARDELLI    1.7         1         1         2948714     DEL
# 1  PORTICO CLASSIC SEAFOOD    1.7         1         1         2948714     DEL
# 2           CHARIS CLASSIC    1.7         2         2         2948714     DEL
# 3                   PACKER    1.7         1         1         2948714     DEL
# 4          CHARIS IMPERIAL    1.7         0         1         2948714     DEL
#
#   transaction_date customer_id_partially_masked
# 0       2021-12-19                        1***0
# 1       2021-12-19                        1***0
# 2       2021-12-19                        1***0
# 3       2021-12-19                        1***0
# 4       2021-12-19                        1***0

# %%
data2.head()
# Out:
#    product_id transaction_date                   timestamp customer_id
# 0   7160636.0       2022-03-14  2022-03-14 20:30:55.000000      ijisi2
# 1   3041183.0       2022-03-14  2022-03-14 14:21:03.000000      ic299j
# 2   5117062.0       2022-03-14  2022-03-14 14:52:25.000000      sss6rj
# 3   4645412.0       2023-02-13  2023-02-13 16:48:48.000000      6sissi
# 4   2146470.0       2023-06-23  2023-06-23 15:23:34.000000      ij9chj

# %%
merged_df = data1.merge(data2, on=["product_id","transaction_date"], how="inner") #merging the two dataset with pandas merge

# Displaying the merged dataset
merged_df
# Out:
#        product_label  product_id product_category    product_major  \
# 0            1247363     8071536     PAPER & DISP     PLATES BOWLS
# 1            1247363     8071536     PAPER & DISP     PLATES BOWLS
# 2            1247363     8071536     PAPER & DISP     PLATES BOWLS
# 3            1247363     8071536     PAPER & DISP     PLATES BOWLS
# 4            1045143     9556481          POULTRY    POULTRY FRESH
# ...              ...         ...              ...              ...
# 75318         295569     3865292          PRODUCE  JUICE/DRINK REF
# 75319         295569     3865292          PRODUCE  JUICE/DRINK REF
# 75320         771715     6533939   CANNED AND DRY  SALT/SEASN/SPCE
# 75321        1235016     7990092     PAPER & DISP             LIDS
# 75322        2252656     7172848   CANNED AND DRY  SALT/SEASN/SPCE
#
#           product_brand    Price  case_qty  ordr_qty  customer_label cuisine  \
# 0      ANCHOR PACKAGING    1.700         2         2         2948714     DEL
# 1      ANCHOR PACKAGING    1.700         1         1         5101946     NaN
# 2      ANCHOR PACKAGING  105.587         1         1         3670941     AMR
# 3      ANCHOR PACKAGING    1.700         4         4       707835787     111
# 4        CHARIS CLASSIC    1.700        10        10         2948714     DEL
# ...                 ...      ...       ...       ...             ...     ...
# 75318    CHARIS NATURAL    1.700         1         1       707835787     111
# 75319    CHARIS NATURAL    1.700         1         1       707835787     111
# 75320    MCCORMICK & CO    1.700         0         2       707835787     111
# 75321  ANCHOR PACKAGING    1.700         1         1       707835787     111
# 75322    CHARIS CLASSIC    1.700         1         1       707835787     111
#
#       transaction_date customer_id_partially_masked  \
# 0           2021-12-19                        1***0
# 1           2021-12-19                        3***4
# 2           2021-12-19                        3***6
# 3           2021-12-19                        8***7
# 4           2021-12-19                        1***0
# ...                ...                          ...
# 75318       2023-04-17                        8***7
# 75319       2023-04-17                        8***7
# 75320       2023-04-17                        8***7
# 75321       2023-04-17                        8***7
# 75322       2023-04-17                        8***7
#
#                         timestamp customer_id
# 0      2021-12-19 13:58:45.000000      h9iicj
# 1      2021-12-19 13:58:45.000000      h9iicj
# 2      2021-12-19 13:58:45.000000      h9iicj
# 3      2021-12-19 13:58:45.000000      h9iicj
# 4      2021-12-19 16:55:13.000000      sss666
# ...                           ...         ...
# 75318  2023-04-17 13:54:09.000000      59925i
# 75319  2023-04-17 15:36:57.000000      sss6rj
# 75320  2023-04-17 16:54:19.000000      59925i
# 75321  2023-04-17 16:34:21.000000      sss666
# 75322  2023-04-17 14:48:00.000000      59925i
#
# [75323 rows x 14 columns]

# %%
# Extracting relevant columns for clustering
X = merged_df[['product_id', 'timestamp']]

# Converting timestamp strings to numerical values (e.g., seconds since a reference date)
merged_df['timestamp'] = pd.to_datetime(merged_df['timestamp'])
reference_date = datetime(2020, 1, 1)  # Choose a reference date
merged_df['timestamp_seconds'] = (merged_df['timestamp'] - reference_date).dt.total_seconds()

# %%
# Creating a new DataFrame with the features for clustering
X_clustering = merged_df[['product_id', 'timestamp_seconds']]

# Standardizing the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_clustering)

# %%
optimal_k = 3

# Applying K-Means clustering with the chosen K value
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
merged_df['Cluster'] = kmeans.fit_predict(X_scaled)

# %%
# plotting an getting the cluster centroid
centroids = kmeans.cluster_centers_

plt.figure(figsize=(10, 6))
sns.scatterplot(data=merged_df, x='product_id', y='timestamp_seconds', hue='Cluster', palette='viridis', s=100)

plt.scatter(centroids[:, 0], centroids[:, 1], c='black', marker='X', s=200, label='Centroids')

plt.legend(title='Cluster')
plt.title('K-Means Clustering of Customers based on Product ID and Timestamp')
plt.xlabel('Product ID')
plt.ylabel('Timestamp (Seconds)')
plt.show()
